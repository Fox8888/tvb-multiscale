# %%
import ANNarchy as ann
# Out:
# ANNarchy 4.6 (4.6.9.7) on linux (posix).

# %%
Izhikevich_Hamker = ann.Neuron(
parameters="""
    a = 0.02
    b = 0.2
    c = -72.0
    d = 6.0
    n0 = 140.
    n1 = 5.0
    n2 = 0.04
    I = 0.0
    tau_refrac = 10.0
    tau_ampa = 10.0
    tau_gaba = 10.0
    E_ampa = 0.0
    E_gaba = -90.0
    tau_syn = 1.0
    C = 1.0
    v_th = 30.0
""",
equations="""
    I_syn_ex = - g_ampa*(v-E_ampa)
    I_syn_in = - g_gaba*(v-E_gaba)
    I_syn = I_syn_ex + I_syn_in - g_base*v
    dg_base/dt = -g_base/tau_syn : init = 0
    dg_ampa/dt = -g_ampa/tau_ampa : init = 0
    dg_gaba/dt = -g_gaba/tau_gaba : init = 0
    dv/dt = n2*v*v+n1*v+n0 - u/C  + I + I_syn : init = -70.
    du/dt = a*(b*(v)-u) : init = -18.55
""",
spike = """
    v>=v_th
""",
reset = """
    v = c
    u = u+d
""",
refractory = """tau_refrac"""
)

# %%
exc1 = ann.Population(1, neuron=Izhikevich_Hamker)

# %%
stimE1 = ann.PoissonPopulation(1, rates=10.0)
proj = ann.Projection(pre=stimE1, post=exc1, target="ampa")
proj.connect_one_to_one(weights=1.0)

# %%
record_from = ["v", "u", "I_syn", "I_syn_ex", "I_syn_in", "g_base", "g_ampa", "g_gaba"]
n_vars = len(record_from)
exc1_m = ann.Monitor(exc1, record_from, period=1.0) 
exc1_spikes_rec = ann.Monitor(exc1, "spike")

# %%
try:
    import shutil
    shutil.rmtree("./annarchy")
    print("Deleted previously compiled network!")
except:
    print("No previously compiled network to delete!")
ann.compile()
# Out:
# Deleted previously compiled network!
# WARNING: Can not find python-config in the same directory as python, trying with the default path...
# Compiling...
# ANNarchyCore0.cpp:1:1: warning: null character(s) ignored
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#  ^
# In file included from /usr/include/python3.7m/pystate.h:11,
#                  from /usr/include/python3.7m/traceback.h:8,
#                  from ANNarchyCore0.cpp:38856:
# /usr/include/python3.7m/pythread.h:122:5: error: #error "Require native threads. See https://bugs.python.org/issue31370"
#  #   error "Require native threads. See https://bugs.python.org/issue31370"
#      ^~~~~
# ANNarchyCore0.cpp:40302:2: error: #endif without #if
#  #endif /* Py_PYTHON_H */
#   ^~~~~
# ANNarchyCore0.cpp:1: error: ‘PyObject’ does not name a type
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#
# ANNarchyCore0.cpp:2:3: error: ‘__Pyx_RefNannyDeclarations’ does not name a type
#    __Pyx_RefNannyDeclarations
#    ^~~~~~~~~~~~~~~~~~~~~~~~~~
# ANNarchyCore0.cpp:4:3: error: expected unqualified-id before ‘{’ token
#    {
#    ^
# ANNarchyCore0.cpp:42:3: error: expected unqualified-id before ‘goto’
#    goto __pyx_L4_argument_unpacking_done;
#    ^~~~
# ANNarchyCore0.cpp:43:3: error: ‘__pyx_L5_argtuple_error’ does not name a type
#    __pyx_L5_argtuple_error:;
#    ^~~~~~~~~~~~~~~~~~~~~~~
# ANNarchyCore0.cpp:44:29: error: expected constructor, destructor, or type conversion before ‘(’ token
#    __Pyx_RaiseArgtupleInvalid("set_single_c", 1, 2, 2, PyTuple_GET_SIZE(__pyx_args)); __PYX_ERR(1, 490, __pyx_L3_error)
#                              ^
# ANNarchyCore0.cpp:44:95: error: expected constructor, destructor, or type conversion before ‘(’ token
#    __Pyx_RaiseArgtupleInvalid("set_single_c", 1, 2, 2, PyTuple_GET_SIZE(__pyx_args)); __PYX_ERR(1, 490, __pyx_L3_error)
#                                                                                                ^
# ANNarchyCore0.cpp:46:21: error: expected constructor, destructor, or type conversion before ‘(’ token
#    __Pyx_AddTraceback("ANNarchyCore0.pop0_wrapper.set_single_c", __pyx_clineno, __pyx_lineno, __pyx_filename);
#                      ^
# ANNarchyCore0.cpp:47:32: error: expected constructor, destructor, or type conversion before ‘;’ token
#    __Pyx_RefNannyFinishContext();
#                                 ^
# ANNarchyCore0.cpp:48:3: error: expected unqualified-id before ‘return’
#    return NULL;
#    ^~~~~~
# ANNarchyCore0.cpp:49:3: error: ‘__pyx_L4_argument_unpacking_done’ does not name a type
#    __pyx_L4_argument_unpacking_done:;
#    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ANNarchyCore0.cpp:50:3: error: ‘__pyx_r’ does not name a type
#    __pyx_r = __pyx_pf_13ANNarchyCore0_12pop0_wrapper_32set_single_c(((struct __pyx_obj_13ANNarchyCore0_pop0_wrapper *)__pyx_v_self), __pyx_v_rank, __pyx_v_value);
#    ^~~~~~~
# ANNarchyCore0.cpp:53:32: error: expected constructor, destructor, or type conversion before ‘;’ token
#    __Pyx_RefNannyFinishContext();
#                                 ^
# ANNarchyCore0.cpp:54:3: error: expected unqualified-id before ‘return’
#    return __pyx_r;
#    ^~~~~~
# ANNarchyCore0.cpp:55:1: error: expected declaration before ‘}’ token
#  }
#  ^
# make: *** [Makefile:4: all] Error 1
# ANNarchyExceptionTraceback (most recent call last)
# <ipython-input-6-d7bffbc97edb> in <module>
#       5 except:
#       6     print("No previously compiled network to delete!")
# ----> 7 ann.compile()
#
# ~/.local/lib/python3.7/site-packages/ANNarchy-4.6.9.7-py3.7-linux-x86_64.egg/ANNarchy/generator/Compiler.py in compile(directory, clean, populations, projections, compiler, compiler_flags, cuda_config, annarchy_json, silent, debug_build, profile_enabled, net_id)
#     274
#     275     # Code Generation
# --> 276     compiler.generate()
#     277
#     278     # Create the Python objects
#
# ~/.local/lib/python3.7/site-packages/ANNarchy-4.6.9.7-py3.7-linux-x86_64.egg/ANNarchy/generator/Compiler.py in generate(self)
#     403         # Perform compilation if something has changed
#     404         if changed or not os.path.isfile(self.annarchy_dir + '/ANNarchyCore' + str(self.net_id) + '.so'):
# --> 405             self.compilation()
#     406
#     407         Global._network[self.net_id]['compiled'] = True
#
# ~/.local/lib/python3.7/site-packages/ANNarchy-4.6.9.7-py3.7-linux-x86_64.egg/ANNarchy/generator/Compiler.py in compilation(self)
#     487             except:
#     488                 pass
# --> 489             Global._error('Compilation failed.')
#     490         else: # Note that the last compilation was successful
#     491             with open(self.annarchy_dir + '/compilation', 'w') as wfile:
#
# ~/.local/lib/python3.7/site-packages/ANNarchy-4.6.9.7-py3.7-linux-x86_64.egg/ANNarchy/core/Global.py in _error(*var_text, **args)
#     611
#     612     if exit:
# --> 613         raise ANNarchyException(text, exit)
#     614     else:
#     615         print('ERROR:' + text)
#
# ANNarchyException: Compilation failed.

# %%
simulation_time = 10000.0 # ms
ann.simulate(simulation_time)

# %%
ts = exc1_m.times()
exc1_ts = exc1_m.get()
spikes = exc1_spikes_rec.get("spike")
spike_times, spike_senders = exc1_spikes_rec.raster_plot(spikes)

# %%
import numpy as np
from matplotlib import pyplot
pyplot.close("all")
rate = len(spike_times) / simulation_time * 1000
f1 = pyplot.figure(figsize=(10, 2.5))
pyplot.plot(spike_times, spike_senders, ".")
pyplot.xlabel("Time (ms)")
pyplot.title("%g (Hz)" % rate)
pyplot.show()
f2, axes = pyplot.subplots(n_vars, 1, sharex=True, figsize=(10, 10))
for i_var, var in enumerate(record_from):
    varts = exc1_ts[var]
    axes[i_var].plot(np.arange(ts[var]["start"][0], len(varts)*exc1_m.period, exc1_m.period), varts)
    axes[i_var].set_title(var)
axes[-1].set_xlabel("Time (ms)")
pyplot.show()

# %%
params = {}
for attr in exc1.attributes:
    params[attr] = getattr(exc1, attr)
print (params)
